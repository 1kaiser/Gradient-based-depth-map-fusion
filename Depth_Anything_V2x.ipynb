# %% [markdown]
# <a href="https://colab.research.google.com/github/1kaiser/Gradient-based-depth-map-fusion/blob/main/Depth_Anything_V2x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/1kaiser/Gradient-based-depth-map-fusion.git
# Out:
# Cloning into 'Gradient-based-depth-map-fusion'...
# remote: Enumerating objects: 363, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 363 (delta 35), reused 28 (delta 28), pack-reused 326 (from 1)
# Receiving objects: 100% (363/363), 190.11 MiB | 20.87 MiB/s, done.
# Resolving deltas: 100% (94/94), done.

# %%
# %cd /content/Gradient-based-depth-map-fusion/Depth-Anything-V2x
# !pip install -r requirements.txt
# Out:
# /content/Gradient-based-depth-map-fusion/Depth-Anything-V2x
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 96.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.6/314.6 kB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 113.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 109.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 12.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.1
#     Uninstalling websockets-14.1:
#       Successfully uninstalled websockets-14.1
# ...

# %%
# %cd /content/Gradient-based-depth-map-fusion/Depth-Anything-V2x
# !mkdir -p checkpoints
# !wget https://github.com/1kaiser/Gradient-based-depth-map-fusion/releases/download/v0.1/depth_anything_v2_vitl.pth -O checkpoints/depth_anything_v2_vitl.pth
# Out:
# /content/Gradient-based-depth-map-fusion/Depth-Anything-V2x
# --2025-01-22 21:56:16--  https://huggingface.co/depth-anything/Depth-Anything-V2-Large/resolve/main/depth_anything_v2_vitl.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.23, 18.164.174.17, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/Gradient-based-depth-map-fusion/Depth-Anything-V2x
# !python run.py \
  --encoder vitl \
  --img-path /content/Gradient-based-depth-map-fusion/Depth-Anything-V2x/assets/examples/demo01.jpg \
  --outdir ./outputs \
  --pred-only \
  --grayscale
# Out:
# /content/Gradient-based-depth-map-fusion/Depth-Anything-V2x
# xFormers not available
# xFormers not available
# ...
